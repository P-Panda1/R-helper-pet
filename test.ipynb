# %%
from googlesearch import search as google_search

# %%
res = google_search("American Independence Movement Causes", num_results=5)

# %%
print(res.)
# Out:
# <generator object search at 0x10a8051c0>
